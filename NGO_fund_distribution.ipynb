# %%
###Country Data analysis

# %% [markdown]
# # PROBLEM STATEMENT
#
# HELP International is an international humanitarian NGO that is committed to fighting poverty and providing the people of backward countries with basic amenities and relief during the time of disasters and natural calamities. It runs a lot of operational projects from time to time along with advocacy drives to raise awareness as well as for funding purposes.
#
# After the recent project that included a lot of awareness drives and funding programmes, they have been able to raise around $ 10 million. Now the CEO of the NGO needs to decide how to use this money strategically and effectively. The significant issues that come while making this decision are mostly related to choosing the countries that are in the direst need of aid.
#
# #Expected result
#
# Your main task is to cluster the countries by the factors mentioned above and then present your solution and recommendations to the CEO using a PPT. You are also supposed to use dimensionality reduction using PCA to get the visualisations of the clusters in a 2-D form.

# %%
#Importing Libraries
import pandas as pd
import numpy as np

# For Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# To Scale our data
from sklearn.preprocessing import scale

# To perform KMeans clustering 
from sklearn.cluster import KMeans

# To perform Hierarchical clustering
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
#reading Dataset
countrydata = pd.read_csv("Country-data.csv",  sep = ',',encoding = "ISO-8859-1", header= 0)
countrydata.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
#Checking for Null objects
countrydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
# country       167 non-null object
# child_mort    167 non-null float64
# exports       167 non-null float64
# health        167 non-null float64
# imports       167 non-null float64
# income        167 non-null int64
# inflation     167 non-null float64
# life_expec    167 non-null float64
# total_fer     167 non-null float64
# gdpp          167 non-null int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.1+ KB

# %% [markdown]
# # PCA procedure

# %%
#Creating separate dataset for PCA analysis
PCA_Data = countrydata[['child_mort','exports','health','imports','income','inflation','life_expec','total_fer','gdpp']]
PCA_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 9 columns):
# child_mort    167 non-null float64
# exports       167 non-null float64
# health        167 non-null float64
# imports       167 non-null float64
# income        167 non-null int64
# inflation     167 non-null float64
# life_expec    167 non-null float64
# total_fer     167 non-null float64
# gdpp          167 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 11.8 KB

# %% [markdown]
# # Splitting data set

# %%
# Splitting the data into train and test
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test = train_test_split(PCA_Data, train_size=0.7,test_size=0.3,random_state=100)

# %% [markdown]
# # After multiple iteration choosing random state for 4

# %%
##PCA analysis
#Improting the PCA module
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized', random_state=4)
x_pca = StandardScaler().fit_transform(PCA_Data)

# %%
pca.fit(x_pca)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=4,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_
# Out:
# array([[-0.41951945,  0.28389698,  0.15083782,  0.16148244,  0.39844111,
#         -0.19317293,  0.42583938, -0.40372896,  0.39264482],
#        [ 0.19288394,  0.61316349, -0.24308678,  0.67182064,  0.02253553,
#         -0.00840447, -0.22270674,  0.15523311, -0.0460224 ],
#        [-0.02954353,  0.14476069, -0.59663237, -0.29992674,  0.3015475 ,
#          0.64251951,  0.11391854,  0.01954925,  0.12297749],
#        [ 0.37065326,  0.00309102,  0.4618975 , -0.07190746,  0.39215904,
#          0.15044176, -0.20379723,  0.37830365,  0.53199457],
#        [-0.16896968,  0.05761584,  0.51800037,  0.25537642, -0.2471496 ,
#          0.7148691 ,  0.1082198 , -0.13526221, -0.18016662],
#        [ 0.20062815, -0.05933283,  0.00727646, -0.03003154,  0.16034699,
#          0.06628537, -0.60112652, -0.75068875,  0.01677876],
#        [-0.07948854, -0.70730269, -0.24983051,  0.59218953,  0.09556237,
#          0.10463252,  0.01848639,  0.02882643,  0.24299776],
#        [-0.68274306, -0.01419742,  0.07249683, -0.02894642,  0.35262369,
#         -0.01153775, -0.50466425,  0.29335267, -0.24969636],
#        [ 0.3275418 , -0.12308207,  0.11308797,  0.09903717,  0.61298247,
#         -0.02523614,  0.29403981, -0.02633585, -0.62564572]])

# %%
colnames = list(PCA_Data.columns)
pcs_df = pd.DataFrame({'PC1':pca.components_[0],'PC2':pca.components_[1], 'PC3':pca.components_[2], 'PC4':pca.components_[3], 'Feature':colnames})
pcs_df.head(10)
# Out:
#         PC1       PC2       PC3       PC4     Feature
# 0 -0.419519  0.192884 -0.029544  0.370653  child_mort
# 1  0.283897  0.613163  0.144761  0.003091     exports
# 2  0.150838 -0.243087 -0.596632  0.461897      health
# 3  0.161482  0.671821 -0.299927 -0.071907     imports
# 4  0.398441  0.022536  0.301548  0.392159      income
# 5 -0.193173 -0.008404  0.642520  0.150442   inflation
# 6  0.425839 -0.222707  0.113919 -0.203797  life_expec
# 7 -0.403729  0.155233  0.019549  0.378304   total_fer
# 8  0.392645 -0.046022  0.122977  0.531995        gdpp

# %%
pcs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
# PC1        9 non-null float64
# PC2        9 non-null float64
# PC3        9 non-null float64
# PC4        9 non-null float64
# Feature    9 non-null object
# dtypes: float64(4), object(1)
# memory usage: 440.0+ bytes

# %%
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.scatter(pcs_df.PC1, pcs_df.PC2)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
for i, txt in enumerate(pcs_df.Feature):
    plt.annotate(txt, (pcs_df.PC1[i],pcs_df.PC2[i]))
plt.tight_layout()
plt.show()

# %% [markdown]
# We see PC1 has Income, gdpp and life expectancy are the variable
# and for PC2 imports and exports

# %%
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.scatter(pcs_df.PC1, pcs_df.PC2)
plt.xlabel('Principal Component 3')
plt.ylabel('Principal Component 4')
for i, txt in enumerate(pcs_df.Feature):
    plt.annotate(txt, (pcs_df.PC3[i],pcs_df.PC4[i]))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Scree Plot

# %%
#Scree plot to determine the number of PCs required
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# from the scree plot we can see 4 PC variables are sufficient

# %%
pca.explained_variance_ratio_
# Out:
# array([0.4595174 , 0.17181626, 0.13004259, 0.11053162, 0.07340211,
#        0.02484235, 0.0126043 , 0.00981282, 0.00743056])

# %% [markdown]
# # Performing Incremental PCA and see if this improves efficiency

# %%
#Using incremental PCA for efficiency 
from sklearn.decomposition import IncrementalPCA
pca_final = IncrementalPCA(n_components=4)

# %%
df_train_pca = pca_final.fit_transform(x_pca)
df_train_pca.shape
# Out:
# (167, 4)

# %%
pca_df_final = pd.DataFrame(df_train_pca)
pca_df_final.head()
# Out:
#           0         1         2         3
# 0 -2.913787  0.088354  0.721003  0.996699
# 1  0.429358 -0.587859  0.321052 -1.171193
# 2 -0.282988 -0.446657 -1.225135 -0.850127
# 3 -2.930969  1.699437 -1.521734  0.875966
# 4  1.031988  0.130488  0.192922 -0.844808

# %%
pca_df_final.rename(columns={0:'PC1',1:'PC2',2:'PC3',3:'PC4'}, inplace= True)
pca_df_final.head()
# Out:
#         PC1       PC2       PC3       PC4
# 0 -2.913787  0.088354  0.721003  0.996699
# 1  0.429358 -0.587859  0.321052 -1.171193
# 2 -0.282988 -0.446657 -1.225135 -0.850127
# 3 -2.930969  1.699437 -1.521734  0.875966
# 4  1.031988  0.130488  0.192922 -0.844808

# %%
pca_df_final.describe(percentiles=[.25,.5,.75,.90,.95,.99])
# Out:
#                 PC1           PC2           PC3           PC4
# count  1.670000e+02  1.670000e+02  1.670000e+02  1.670000e+02
# mean   2.659217e-17  1.429329e-17 -2.476396e-17  1.662011e-17
# std    2.039726e+00  1.247144e+00  1.083371e+00  1.000238e+00
# min   -4.878925e+00 -2.991196e+00 -5.590269e+00 -1.582161e+00
# 25%   -1.383574e+00 -7.481349e-01 -4.154744e-01 -7.901529e-01
# 50%    2.418370e-02 -9.344038e-02  1.937511e-01 -2.939462e-01
# 75%    1.224232e+00  5.568934e-01  5.140716e-01  7.090722e-01
# 90%    2.461331e+00  1.276336e+00  1.067970e+00  1.226926e+00
# 95%    3.105192e+00  1.716160e+00  1.465341e+00  1.775725e+00
# 99%    4.761754e+00  4.808004e+00  2.531317e+00  2.780284e+00
# max    6.918224e+00  6.685374e+00  2.857371e+00  3.150200e+00

# %%
countrydata_df = countrydata.reset_index()
countrydata_df.head()
# Out:
#    index              country  child_mort  exports  health  imports  income  \
# 0      0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1      1              Albania        16.6     28.0    6.55     48.6    9930
# 2      2              Algeria        27.3     38.4    4.17     31.4   12900
# 3      3               Angola       119.0     62.3    2.85     42.9    5900
# 4      4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
combined_country = pd.concat([countrydata_df,pca_df_final], axis = 1)
combined_country.head()
# Out:
#    index              country  child_mort  exports  health  imports  income  \
# 0      0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1      1              Albania        16.6     28.0    6.55     48.6    9930
# 2      2              Algeria        27.3     38.4    4.17     31.4   12900
# 3      3               Angola       119.0     62.3    2.85     42.9    5900
# 4      4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp       PC1       PC2       PC3  \
# 0       9.44        56.2       5.82    553 -2.913787  0.088354  0.721003
# 1       4.49        76.3       1.65   4090  0.429358 -0.587859  0.321052
# 2      16.10        76.5       2.89   4460 -0.282988 -0.446657 -1.225135
# 3      22.40        60.1       6.16   3530 -2.930969  1.699437 -1.521734
# 4       1.44        76.8       2.13  12200  1.031988  0.130488  0.192922
#
#         PC4
# 0  0.996699
# 1 -1.171193
# 2 -0.850127
# 3  0.875966
# 4 -0.844808

# %%
combined_country = combined_country.drop(['child_mort','exports','health','imports','income','inflation','life_expec','total_fer','gdpp'], axis = 1)
combined_country.head()
# Out:
#    index              country       PC1       PC2       PC3       PC4
# 0      0          Afghanistan -2.913787  0.088354  0.721003  0.996699
# 1      1              Albania  0.429358 -0.587859  0.321052 -1.171193
# 2      2              Algeria -0.282988 -0.446657 -1.225135 -0.850127
# 3      3               Angola -2.930969  1.699437 -1.521734  0.875966
# 4      4  Antigua and Barbuda  1.031988  0.130488  0.192922 -0.844808

# %% [markdown]
# # Hopkins Statistics

# %%
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan
 
def hopkins(X):
    d = X.shape[1]
    #d = len(vars) # columns
    n = len(X) # rows
    m = int(0.1 * n) 
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)
 
    rand_X = sample(range(0, n, 1), m)
 
    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])
 
    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0
 
    return H

# %%
hopkins(pca_df_final)
# Out:
# 0.8017463010716499

# %% [markdown]
# # K-Means analysis

# %%
# Kmeans with K=2
model_clus2 = KMeans(n_clusters = 2, max_iter=50)
model_clus2.fit(pca_df_final)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=50,
#     n_clusters=2, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# # Silhouette Score

# %%
from sklearn.metrics import silhouette_score
sse_ = []
for k in range(2, 15):
    kmeans = KMeans(n_clusters=k).fit(pca_df_final)
    sse_.append([k, silhouette_score(pca_df_final, kmeans.labels_)])

# %%
plt.plot(pd.DataFrame(sse_)[0], pd.DataFrame(sse_)[1]);

# %%
# sum of squared distances
ssd = []
for num_clusters in list(range(1,21)):
    model_clus = KMeans(n_clusters = num_clusters, max_iter=50)
    model_clus.fit(pca_df_final)
    ssd.append(model_clus.inertia_)

plt.plot(ssd)

# %%
pca_df_final.head()
# Out:
#         PC1       PC2       PC3       PC4
# 0 -2.913787  0.088354  0.721003  0.996699
# 1  0.429358 -0.587859  0.321052 -1.171193
# 2 -0.282988 -0.446657 -1.225135 -0.850127
# 3 -2.930969  1.699437 -1.521734  0.875966
# 4  1.031988  0.130488  0.192922 -0.844808

# %%
# analysis of clusters formed
combined_country.index = pd.RangeIndex(len(combined_country.index))
combined_country_km2 = pd.concat([combined_country, pd.Series(model_clus2.labels_)], axis=1)
combined_country_km2.columns = ['Index','Country', 'PC1', 'PC2', 'PC3','PC4', 'ClusterID']
combined_country_km2.head()
# Out:
#    Index              Country       PC1       PC2       PC3       PC4  \
# 0      0          Afghanistan -2.913787  0.088354  0.721003  0.996699
# 1      1              Albania  0.429358 -0.587859  0.321052 -1.171193
# 2      2              Algeria -0.282988 -0.446657 -1.225135 -0.850127
# 3      3               Angola -2.930969  1.699437 -1.521734  0.875966
# 4      4  Antigua and Barbuda  1.031988  0.130488  0.192922 -0.844808
#
#    ClusterID
# 0          1
# 1          0
# 2          0
# 3          1
# 4          0

# %%
combined_country_km2['ClusterID'].value_counts(dropna = False)
# Out:
# 0    99
# 1    68
# Name: ClusterID, dtype: int64

# %%
combined_country_km2.loc[combined_country_km2['ClusterID']== 0]
# Out:
#      Index                         Country       PC1       PC2       PC3  \
# 1        1                         Albania  0.429358 -0.587859  0.321052
# 2        2                         Algeria -0.282988 -0.446657 -1.225135
# 4        4             Antigua and Barbuda  1.031988  0.130488  0.192922
# 5        5                       Argentina  0.028470 -1.756721 -0.793520
# 6        6                         Armenia -0.102849 -0.567476 -0.277669
# 7        7                       Australia  2.339456 -1.998120 -0.237052
# 8        8                         Austria  2.973859 -0.734849  0.548421
# 9        9                      Azerbaijan -0.180006 -0.393752 -0.864255
# 10      10                         Bahamas  1.266074 -0.665088  0.453533
# 11      11                         Bahrain  1.670737  0.560394 -1.020168
# 13      13                        Barbados  1.080093 -0.486679  0.649528
# 14      14                         Belarus  0.583540  0.553393 -0.430647
# 15      15                         Belgium  3.145437  0.667278  0.708087
# 16      16                          Belize  0.209345  0.690214  0.230509
# 18      18                          Bhutan -0.157595  0.777245  0.269734
# 20      20          Bosnia and Herzegovina  0.997787 -0.966161  1.584872
# 22      22                          Brazil  0.141884 -2.146022  0.183137
# 23      23                          Brunei  2.459953  0.021044 -3.074741
# 24      24                        Bulgaria  0.905430  0.026819  0.450745
# 29      29                          Canada  2.543935 -1.726562  0.421128
# 30      30                      Cape Verde -0.159550  0.338681  0.220677
# 33      33                           Chile  0.953875 -1.069253 -0.129124
# 34      34                           China  0.056215 -1.191313 -0.477243
# 35      35                        Colombia  0.120226 -1.772812  0.212410
# 39      39                      Costa Rica  0.941591 -1.340673  0.887942
# 41      41                         Croatia  1.147616 -0.849478  0.383416
# 42      42                          Cyprus  2.172277 -0.009520 -0.295254
# 43      43                  Czech Republic  2.052132  0.418164  0.532325
# 44      44                         Denmark  3.011286 -0.863838  0.377635
# 45      45              Dominican Republic -0.232432 -0.885222  0.000748
# ..     ...                             ...       ...       ...       ...
# 118    118                        Paraguay  0.118263  0.360471  0.038677
# 119    119                            Peru -0.021948 -1.092611 -0.462892
# 121    121                          Poland  1.216764 -0.662194  0.288988
# 122    122                        Portugal  1.814629 -1.450428  0.967318
# 123    123                           Qatar  4.235296 -0.215248 -3.813942
# 124    124                         Romania  0.570760 -0.641971 -0.135515
# 125    125                          Russia  0.164664 -1.057890 -1.104564
# 128    128                    Saudi Arabia  0.858074 -0.175554 -1.911677
# 130    130                          Serbia  0.835373 -0.858708  1.084387
# 131    131                      Seychelles  1.598669  2.925514  0.329580
# 133    133                       Singapore  5.783703  6.685374 -0.608365
# 134    134                 Slovak Republic  2.030440  1.052535  0.891071
# 135    135                        Slovenia  2.279618  0.193466  0.820114
# 138    138                     South Korea  1.917223 -0.428665 -0.161061
# 139    139                           Spain  2.017891 -1.789472  0.360344
# 140    140                       Sri Lanka -0.571889 -0.978767 -1.739270
# 141    141  St. Vincent and the Grenadines  0.024184 -0.020816 -0.007853
# 143    143                        Suriname  0.172376 -0.093440 -0.011311
# 144    144                          Sweden  2.817276 -0.919824  0.096053
# 145    145                     Switzerland  4.087927 -0.431372  0.292454
# 148    148                        Thailand  0.924634  0.825687 -0.384426
# 152    152                         Tunisia  0.602077  0.172077  0.231449
# 153    153                          Turkey  0.401199 -1.412591 -0.250298
# 156    156                         Ukraine  0.306435 -0.079141  0.163638
# 157    157            United Arab Emirates  2.427320  1.157104 -1.845482
# 158    158                  United Kingdom  2.067034 -1.540084  0.242033
# 159    159                   United States  2.644644 -2.991196  1.829989
# 160    160                         Uruguay  0.617711 -1.430764  0.238559
# 163    163                       Venezuela -0.537432 -1.177328 -2.922300
# 164    164                         Vietnam  0.502767  1.408012  0.322218
#
#           PC4  ClusterID
# 1   -1.171193          0
# 2   -0.850127          0
# 4   -0.844808          0
# 5   -0.052486          0
# 6   -1.458321          0
# 7    1.132490          0
# 8    1.192561          0
# 9   -0.426657          0
# 10   0.059479          0
# 11  -0.178515          0
# 13  -0.533559          0
# 14  -1.053720          0
# 15   1.067254          0
# 16  -1.091104          0
# 18  -1.046412          0
# 20  -0.677552          0
# 22  -0.178092          0
# 23   0.860320          0
# 24  -1.002968          0
# 29   1.327507          0
# 30  -1.330850          0
# 33  -0.446709          0
# 34  -1.260072          0
# 35  -0.714628          0
# 39  -0.305137          0
# 41  -0.626407          0
# 42  -0.293946          0
# 43  -0.420532          0
# 44   1.776832          0
# 45  -0.645933          0
# ..        ...        ...
# 118 -0.951248          0
# 119 -1.048607          0
# 121 -0.698488          0
# 122  0.165640          0
# 123  2.540293          0
# 124 -1.017410          0
# 125 -0.624639          0
# 128  0.242042          0
# 130 -0.553033          0
# 131 -1.392052          0
# 133  0.094262          0
# 134 -0.403044          0
# 135 -0.090242          0
# 138 -0.465325          0
# 139  0.264600          0
# 140 -1.360112          0
# 141 -1.215981          0
# 143 -0.380207          0
# 144  1.250517          0
# 145  2.307296          0
# 148 -1.582161          0
# 152 -1.125839          0
# 153 -0.555292          0
# 156 -0.915514          0
# 157  0.321000          0
# 158  0.794529          0
# 159  2.768047          0
# 160 -0.365984          0
# 163 -0.126091          0
# 164 -1.116014          0
#
# [99 rows x 7 columns]

# %% [markdown]
# # K-Means for K=4

# %%
# Kmeans with K=4
model_clus4 = KMeans(n_clusters = 4, max_iter=40)
model_clus4.fit(pca_df_final)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=40,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# # Silhoutte Score for K = 4

# %%
sse_4 = []
for k in range(2, 15):
    kmeans = KMeans(n_clusters=k).fit(pca_df_final)
    sse_4.append([k, silhouette_score(pca_df_final, kmeans.labels_)])

# %%
plt.plot(pd.DataFrame(sse_4)[0], pd.DataFrame(sse_4)[1]);

# %% [markdown]
#  # Sum of Squared Distances

# %%
# sum of squared distances
ssd = []
for num_clusters in list(range(1,21)):
    model_clus = KMeans(n_clusters = num_clusters, max_iter=40)
    model_clus.fit(pca_df_final)
    ssd.append(model_clus.inertia_)

plt.plot(ssd)

# %%
# analysis of clusters formed
combined_country.index = pd.RangeIndex(len(combined_country.index))
combined_country_km4 = pd.concat([combined_country, pd.Series(model_clus4.labels_)], axis=1)
combined_country_km4.columns = ['Index','Country', 'PC1', 'PC2', 'PC3','PC4', 'ClusterID']
combined_country_km4.head()
# Out:
#    Index              Country       PC1       PC2       PC3       PC4  \
# 0      0          Afghanistan -2.913787  0.088354  0.721003  0.996699
# 1      1              Albania  0.429358 -0.587859  0.321052 -1.171193
# 2      2              Algeria -0.282988 -0.446657 -1.225135 -0.850127
# 3      3               Angola -2.930969  1.699437 -1.521734  0.875966
# 4      4  Antigua and Barbuda  1.031988  0.130488  0.192922 -0.844808
#
#    ClusterID
# 0          1
# 1          2
# 2          2
# 3          1
# 4          2

# %%
combined_country_km4['ClusterID'].value_counts(dropna = False)
# Out:
# 2    87
# 1    47
# 0    30
# 3     3
# Name: ClusterID, dtype: int64

# %%
combined_country_km4.loc[combined_country_km4['ClusterID']== 1]
# Out:
#      Index                   Country       PC1       PC2       PC3       PC4  \
# 0        0               Afghanistan -2.913787  0.088354  0.721003  0.996699
# 3        3                    Angola -2.930969  1.699437 -1.521734  0.875966
# 17      17                     Benin -2.679195  0.391235  0.139349  0.321834
# 21      21                  Botswana -0.881545  0.461932  0.620368  0.384517
# 25      25              Burkina Faso -3.125200  0.023315  0.410699  1.096936
# 26      26                   Burundi -2.895611 -0.419723  1.434451  1.773143
# 28      28                  Cameroon -2.814184  0.054609  0.238777  0.580951
# 31      31  Central African Republic -3.974389  0.357584  0.186493  0.973005
# 32      32                      Chad -3.562849  1.267213  0.025108  1.247079
# 36      36                   Comoros -2.098048  0.326629  0.255810 -0.097318
# 37      37          Congo, Dem. Rep. -3.169030  1.060528  0.088988  1.552543
# 38      38               Congo, Rep. -1.722746  2.185040 -1.476156 -0.115317
# 40      40             Cote d'Ivoire -2.585554  1.191880  0.176128  0.688935
# 49      49         Equatorial Guinea -1.289990  2.377580 -1.721711  1.764928
# 50      50                   Eritrea -2.477492 -0.628045 -0.887555 -0.445521
# 55      55                     Gabon -1.421527  0.320594 -1.573430  0.232278
# 56      56                    Gambia -2.216490  0.206132  0.336199  0.305584
# 59      59                     Ghana -2.052895  0.386277 -0.400302  0.093042
# 63      63                    Guinea -2.969769  0.728356 -0.391573  0.680401
# 64      64             Guinea-Bissau -2.837372 -0.106572  1.174178  1.129905
# 66      66                     Haiti -4.418771  1.730522  1.428622  1.798442
# 72      72                      Iraq -1.024061 -0.271765 -0.122332  0.542748
# 80      80                     Kenya -1.879351 -0.190238  0.157415 -0.257880
# 81      81                  Kiribati -1.239107  0.367490  2.435513  0.525576
# 84      84                       Lao -1.530134  0.542634 -0.170271 -0.401174
# 87      87                   Lesotho -1.803591  2.042345  2.594980  0.998154
# 88      88                   Liberia -1.771653  1.056052  2.498521  1.101975
# 93      93                Madagascar -2.138513  0.332862 -0.293062 -0.292988
# 94      94                    Malawi -2.980519  0.212538  0.200578  0.842287
# 97      97                      Mali -3.417868  0.536630  0.157566  1.111984
# 99      99                Mauritania -1.951631  1.391530 -0.695549  0.199711
# 106    106                Mozambique -2.923687  0.879892  0.213193  0.651606
# 108    108                   Namibia -1.045406  0.995331  0.718050  0.084503
# 112    112                     Niger -3.455369  0.941773  0.495818  1.156428
# 113    113                   Nigeria -4.878925  0.040809 -5.590269  2.350105
# 116    116                  Pakistan -2.364931 -0.490738 -1.116140 -0.365223
# 126    126                    Rwanda -1.680055 -1.010143  1.478579  0.643550
# 129    129                   Senegal -1.915859  0.072373  0.435325  0.044637
# 132    132              Sierra Leone -3.377982 -0.222711  1.497511  2.524337
# 137    137              South Africa -1.192987 -0.557571  0.721908  0.537899
# 142    142                     Sudan -2.316482 -0.761420 -0.706209  0.498155
# 147    147                  Tanzania -2.555322 -0.224784  0.053578  0.475616
# 149    149               Timor-Leste -2.363374 -1.155928 -0.272332  1.122420
# 150    150                      Togo -2.000656  0.943569  1.194488  0.551456
# 155    155                    Uganda -2.853673 -0.356843  0.723779  1.280859
# 165    165                     Yemen -1.882505 -0.093454 -1.055348  0.056400
# 166    166                    Zambia -2.864009  0.483481 -0.228784  0.828041
#
#      ClusterID
# 0            1
# 3            1
# 17           1
# 21           1
# 25           1
# 26           1
# 28           1
# 31           1
# 32           1
# 36           1
# 37           1
# 38           1
# 40           1
# 49           1
# 50           1
# 55           1
# 56           1
# 59           1
# 63           1
# 64           1
# 66           1
# 72           1
# 80           1
# 81           1
# 84           1
# 87           1
# 88           1
# 93           1
# 94           1
# 97           1
# 99           1
# 106          1
# 108          1
# 112          1
# 113          1
# 116          1
# 126          1
# 129          1
# 132          1
# 137          1
# 142          1
# 147          1
# 149          1
# 150          1
# 155          1
# 165          1
# 166          1

# %% [markdown]
# # Heirarchical Clustering analysis of complete and single method

# %%
#Heirarchical clustering
# heirarchical clustering
mergings = linkage(pca_df_final, method = "complete", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
#Heirarchical clustering
# heirarchical clustering
mergings = linkage(pca_df_final, method = "single", metric='euclidean')
dendrogram(mergings)
plt.show()

# %%
combined_country_km4.mean()
# Out:
# Index        8.300000e+01
# PC1          2.659217e-17
# PC2          1.429329e-17
# PC3         -2.476396e-17
# PC4          1.662011e-17
# ClusterID    1.377246e+00
# dtype: float64

# %% [markdown]
# # Result analysis
# Cluster 1 are the countries which require more allocation of the aide, followed by countries in cluster 2, then countries in cluster 0 and last are the rich countries in cluster 3
